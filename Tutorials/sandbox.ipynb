# %%
# !pip install skillNer
# !python -m spacy download en_core_web_lg
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for skillNer: filename=skillNer-1.0.3-py3-none-any.whl size=25649 sha256=2087d44c7113b0402cde3cd616ab0d12f7082c3592cf63bc75d407cc1ea0c0f9
#   Stored in directory: /Users/shachafporan/Library/Caches/pip/wheels/eb/a1/1a/735667a07483c24897ef0857e0dcbc9bd9d2c0cd0c840c7d7d
# Successfully built skillNer
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/shachafporan/repos/skill_ner/venv/bin/python -m pip install --upgrade pip' command.
# ...
#      |████████████████████████████████| 587.7 MB 68 kB/s              eta 0:00:22 eta 0:00:22██▏                            | 59.0 MB 23.3 MB/s eta 0:00:23██▉                            | 70.0 MB 22.9 MB/s eta 0:00:23██▉                            | 70.5 MB 22.9 MB/s eta 0:00:23MB/s eta 0:00:22MB/s eta 0:00:22MB/s eta 0:00:21            | 155.5 MB 635 kB/s eta 0:11:20
# ...

# %%
# imports
import spacy
import en_core_web_lg
from spacy.matcher import PhraseMatcher

# import skill extractor
from skillNer.skill_extractor_class import SkillExtractor
from skillNer.general_params import SKILL_DB


# init params of skill extractor
nlp = en_core_web_lg.load()
# init skill extractor
skill_extractor = SkillExtractor(nlp, SKILL_DB, PhraseMatcher)
# Out:
# loading full_matcher ...
# loading abv_matcher ...
# loading full_uni_matcher ...
# loading low_form_matcher ...
# loading token_matcher ...

# %%
# extract skills from job_description
job_description = """
You are a hard-working Python developer presentor with a solid experience in web development and public speaking. You can also manage projects. You quickly adapt to new environments 
and speak English and French, both of them fluently.
"""

annotations = skill_extractor.annotate(job_description)

# %%
# inspect annotations
skill_extractor.describe(annotations)
# Out:
#         <head>
#             <link
#                 id="external-css"
#                 rel="stylesheet"
#                 type="text/css"
#                 href="https://unpkg.com/tailwindcss@^2/dist/tailwind.min.css"
#                 media="all"
#             />
#         </head>
#
#         <body>
#             <div id="root" class="px-4 leading-10 mb-24">
#                 &nbspyou are a hard working&nbsp
#         <span class='relative p-1 text-white rounded-md border bg-red-500' onmouseleave='mouseLeaveHandler_KS125LS6N7WP4S6SFTCK_377()'onmouseenter='mouseEnterHandler_KS125LS6N7WP4S6SFTCK_377()'>
#             python
#         <span class='text-xs text-white font-bold' >
#              ( Hard Skill )
#         </span>
#
#         <div class='absolute shadow-lg z-40 bg-white flex-col text-sm text-black p-2 border left-0 -bottom-15' id='KS125LS6N7WP4S6SFTCK_377'style='display: none;'>
#
#         <div class='flex grid-cols-2 gap-2 mb-4' >
#
# ...

# %%
print(annotations)
# Out:
# {'text': 'you are a hard working python developer presentor with a solid experience in web development and public speaking you can also manage projects you quickly adapt to new environments and speak english and french both of them fluently', 'results': {'full_matches': [{'skill_id': 'KS122Z36QK3N5097B5JH', 'doc_node_value': 'web development', 'score': 1, 'doc_node_id': [13, 14]}, {'skill_id': 'KS124JZ5VYRZ5MJ85N2B', 'doc_node_value': 'public speak', 'score': 1, 'doc_node_id': [16, 17]}], 'ngram_scored': [{'skill_id': 'KS125LS6N7WP4S6SFTCK', 'doc_node_id': [5], 'doc_node_value': 'python', 'type': 'fullUni', 'score': 1, 'len': 1}, {'skill_id': 'KS1267F6MSPN366LX7ST', 'doc_node_id': [21, 22], 'doc_node_value': 'manage projects', 'type': 'lowSurf', 'score': 2, 'len': 2}, {'skill_id': 'KS120626HMWCXJWJC7VK', 'doc_node_id': [25], 'doc_node_value': 'adapt', 'type': 'lowSurf', 'score': 0.5245310068130493, 'len': 1}, {'skill_id': 'KS123K75YYK8VGH90NCS', 'doc_node_id': [31], 'doc_node_value':
# ...
